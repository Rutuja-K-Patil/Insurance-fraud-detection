# %% [markdown]
# # Import Libraries:

# %%
#Predicting Insurance Claim Amounts

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_excel("Maturity_Data.xlsx")
df
# Out:
#      Policy Number  Branch        DOC Claim Due Date  Plan  Policy Term  \
# 0        100614068    4015 2004-06-09     2007-03-08    14           20
# 1        102314313    4015 2012-08-29     2014-02-21   111            8
# 2        103484630    4015 1991-11-16     2007-01-24   111           20
# 3        103807155    4015 1992-10-13     2010-05-25   106           20
# 4        106977991    4015 1991-09-13     1998-08-05    75           15
# ..             ...     ...        ...            ...   ...          ...
# 655      992994062    4015 2007-11-06     2014-05-05   801           20
# 656      995226828    4015 1990-10-04     2002-04-22   111           15
# 657      995619255    4015 1992-06-13     2009-05-07   801            8
# 658      997677788    4015 2017-08-13     2008-11-04   111           15
# 659      997835424    4015 1996-01-15     2015-08-01    75           20
#
#       Claim Amount  Vested Bonus  Interim Bonus  Final Additional Bonus  \
# 0     38563.221899  33701.647606    9339.244017             6089.621520
# 1     51666.039139  48711.268825    8972.874719             8406.386946
# 2     88906.524820  33410.777170    5533.966318             3261.268054
# 3    115663.536961  35299.418047    3548.046346              394.057076
# 4     82153.702496  32676.704921    7189.802411             7869.917926
# ..             ...           ...            ...                     ...
# 655   28307.261217  26322.799270    9544.529839             8895.742139
# 656  135585.986650   5754.263335    2457.847792             1312.057764
# 657  119383.675764   3047.881855    2687.171521              737.093896
# 658   34245.539340  12329.503417    9509.902621             4185.656861
# 659   59483.283148  22964.141837    9940.657360             8025.802829
#
#          Premium  Mode Master FUP  Anomaly Flag
# 0    4063.435561     3 2001-12-01             0
# 1    3294.850477     3 1997-12-01             0
# 2    1372.759863    12 2002-12-01             0
# 3    3083.742767     3 2002-12-01             0
# 4    2106.719340     6 2012-03-01             0
# ..           ...   ...        ...           ...
# 655  3974.582725     3 2003-09-01             0
# 656  1385.207547    12 1997-12-01             0
# 657  1584.796212     3 1997-12-01             0
# 658  4200.645575    12 2012-03-01             0
# 659  4182.606997     3 1997-12-01             1
#
# [660 rows x 14 columns]

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#    Policy Number  Branch        DOC Claim Due Date  Plan  Policy Term  \
# 0      100614068    4015 2004-06-09     2007-03-08    14           20
# 1      102314313    4015 2012-08-29     2014-02-21   111            8
# 2      103484630    4015 1991-11-16     2007-01-24   111           20
# 3      103807155    4015 1992-10-13     2010-05-25   106           20
# 4      106977991    4015 1991-09-13     1998-08-05    75           15
#
#     Claim Amount  Vested Bonus  Interim Bonus  Final Additional Bonus  \
# 0   38563.221899  33701.647606    9339.244017             6089.621520
# 1   51666.039139  48711.268825    8972.874719             8406.386946
# 2   88906.524820  33410.777170    5533.966318             3261.268054
# 3  115663.536961  35299.418047    3548.046346              394.057076
# 4   82153.702496  32676.704921    7189.802411             7869.917926
#
#        Premium  Mode Master FUP  Anomaly Flag
# 0  4063.435561     3 2001-12-01             0
# 1  3294.850477     3 1997-12-01             0
# 2  1372.759863    12 2002-12-01             0
# 3  3083.742767     3 2002-12-01             0
# 4  2106.719340     6 2012-03-01             0

# %%
df.tail()
# Out:
#      Policy Number  Branch        DOC Claim Due Date  Plan  Policy Term  \
# 655      992994062    4015 2007-11-06     2014-05-05   801           20
# 656      995226828    4015 1990-10-04     2002-04-22   111           15
# 657      995619255    4015 1992-06-13     2009-05-07   801            8
# 658      997677788    4015 2017-08-13     2008-11-04   111           15
# 659      997835424    4015 1996-01-15     2015-08-01    75           20
#
#       Claim Amount  Vested Bonus  Interim Bonus  Final Additional Bonus  \
# 655   28307.261217  26322.799270    9544.529839             8895.742139
# 656  135585.986650   5754.263335    2457.847792             1312.057764
# 657  119383.675764   3047.881855    2687.171521              737.093896
# 658   34245.539340  12329.503417    9509.902621             4185.656861
# 659   59483.283148  22964.141837    9940.657360             8025.802829
#
#          Premium  Mode Master FUP  Anomaly Flag
# 655  3974.582725     3 2003-09-01             0
# 656  1385.207547    12 1997-12-01             0
# 657  1584.796212     3 1997-12-01             0
# 658  4200.645575    12 2012-03-01             0
# 659  4182.606997     3 1997-12-01             1

# %%
df.shape
# Out:
# (660, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Policy Number           660 non-null    int64
#  1   Branch                  660 non-null    int64
#  2   DOC                     660 non-null    datetime64[ns]
#  3   Claim Due Date          660 non-null    datetime64[ns]
#  4   Plan                    660 non-null    int64
#  5   Policy Term             660 non-null    int64
#  6   Claim Amount            660 non-null    float64
#  7   Vested Bonus            660 non-null    float64
#  8   Interim Bonus           660 non-null    float64
#  9   Final Additional Bonus  660 non-null    float64
#  10  Premium                 660 non-null    float64
#  11  Mode                    660 non-null    int64
#  12  Master FUP              660 non-null    datetime64[ns]
#  13  Anomaly Flag            660 non-null    int64
# dtypes: datetime64[ns](3), float64(5), int64(6)
# memory usage: 72.3 KB

# %%
df.isnull().sum()
# Out:
# Policy Number             0
# Branch                    0
# DOC                       0
# Claim Due Date            0
# Plan                      0
# Policy Term               0
# Claim Amount              0
# Vested Bonus              0
# Interim Bonus             0
# Final Additional Bonus    0
# Premium                   0
# Mode                      0
# Master FUP                0
# Anomaly Flag              0
# dtype: int64

# %%
df.describe()
# Out:
#        Policy Number  Branch                  DOC  \
# count   6.600000e+02   660.0                  660
# mean    5.368162e+08  4015.0  2002-11-13 12:00:00
# min     1.006141e+08  4015.0  1990-01-03 00:00:00
# 25%     3.231482e+08  4015.0  1995-02-12 00:00:00
# 50%     5.315294e+08  4015.0  2002-05-17 12:00:00
# 75%     7.572095e+08  4015.0  2009-08-21 12:00:00
# max     9.978354e+08  4015.0  2019-10-04 00:00:00
# std     2.566467e+08     0.0                  NaN
#
#                       Claim Due Date        Plan  Policy Term   Claim Amount  \
# count                            660  660.000000   660.000000     660.000000
# mean   2007-10-29 14:45:49.090909184  223.871212    14.446970   89360.678463
# min              1990-01-07 00:00:00   14.000000     8.000000   10725.402497
# 25%              2001-08-13 12:00:00   75.000000     8.000000   55757.494889
# 50%              2008-12-19 00:00:00  106.000000    15.000000   87340.890238
# 75%              2014-11-27 00:00:00  111.000000    20.000000  121159.523297
# max              2019-12-22 00:00:00  801.000000    20.000000  198017.318405
# std                              NaN  293.504770     4.887062   42786.075945
#
#        Vested Bonus  Interim Bonus  Final Additional Bonus       Premium  \
# count    660.000000     660.000000              660.000000    660.000000
# mean   24969.385179    4965.241710             4908.834035   3033.502710
# min        0.000000       0.000000                0.000000    193.000000
# 25%    13068.237401    2429.554864             2261.500676   2041.618086
# 50%    25008.104368    4972.761946             4893.369514   3043.877088
# 75%    36438.648823    7526.236852             7458.618681   3986.364273
# max    49978.600351    9998.995526             9974.690996  20000.000000
# std    14305.343440    2946.656550             2966.336216   1300.846029
#
#              Mode                     Master FUP  Anomaly Flag
# count  660.000000                            660    660.000000
# mean     7.040909  2003-06-30 14:28:21.818181760      0.227273
# min      3.000000            1997-12-01 00:00:00      0.000000
# 25%      3.000000            2001-12-01 00:00:00      0.000000
# 50%      6.000000            2002-12-01 00:00:00      0.000000
# 75%     12.000000            2003-09-01 00:00:00      0.000000
# max     12.000000            2012-03-01 00:00:00      1.000000
# std      3.749739                            NaN      0.419388

# %%
df.dtypes
# Out:
# Policy Number                      int64
# Branch                             int64
# DOC                       datetime64[ns]
# Claim Due Date            datetime64[ns]
# Plan                               int64
# Policy Term                        int64
# Claim Amount                     float64
# Vested Bonus                     float64
# Interim Bonus                    float64
# Final Additional Bonus           float64
# Premium                          float64
# Mode                               int64
# Master FUP                datetime64[ns]
# Anomaly Flag                       int64
# dtype: object

# %%
df = df.drop_duplicates()
df.shape
# Out:
# (660, 14)

# %%
df.columns
# Out:
# Index(['Policy Number', 'Branch', 'DOC', 'Claim Due Date', 'Plan',
#        'Policy Term', 'Claim Amount', 'Vested Bonus', 'Interim Bonus',
#        'Final Additional Bonus', 'Premium', 'Mode', 'Master FUP',
#        'Anomaly Flag'],
#       dtype='object')

# %% [markdown]
# # Find zero values

# %%
#Count the zero values from Dataframe

def columns_with_zeros(df):
    zero_counts = df.eq(0).sum()
    for column_name, count in zero_counts.items():
        if count > 0:
            print(f"Column '{column_name}' has zero's : {count} ")

columns_with_zeros(df)
# Out:
# Column 'Vested Bonus' has zero's : 6
# Column 'Interim Bonus' has zero's : 5
# Column 'Final Additional Bonus' has zero's : 10
# Column 'Anomaly Flag' has zero's : 510

# %% [markdown]
# # Correlation Matrix

# %%
import seaborn as sns
corrmat = df.corr()
top_corr_features = corrmat.index

plt.figure(figsize=(30,30))
g = sns.heatmap(df[top_corr_features].corr(), annot=True, cmap='RdYlGn')

# %%
df.drop('Branch',axis = 1,inplace =True)
df.drop('DOC',axis = 1,inplace = True)
df.drop('Claim Due Date',axis =1 ,inplace = True)
df.drop('Master FUP',axis = 1,inplace = True)

# %%
import seaborn as sns
corrmat = df.corr()
top_corr_features = corrmat.index

plt.figure(figsize=(30,30))
g = sns.heatmap(df[top_corr_features].corr(), annot=True, cmap='RdYlGn')

# %% [markdown]
# # Outlier Detection

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def visualize_and_find_outliers(df):
    for column in df.columns[:-1]:  
        if df[column].dtype in ['int64', 'float64']: 
            plt.figure(figsize=(5, 6))
            sns.boxplot(x=df[column])

            plt.title(f'Boxplot of {column}')
            plt.xlabel(column)

            plt.show()

            Q1 = df[column].quantile(0.25)
            Q3 = df[column].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)][column]

            print(f'Outliers in {column}:')
            if len(outliers) == 0:
                print('No outliers found.')
            else:
                print(outliers)

visualize_and_find_outliers(df)
# Out:
# Outliers in Policy Number:
# No outliers found.
# Outliers in Plan:
# 0       14
# 6      801
# 16      14
# 19     801
# 23      14
#       ...
# 643     14
# 645     14
# 651    801
# 655    801
# 657    801
# Name: Plan, Length: 261, dtype: int64
# Outliers in Policy Term:
# No outliers found.
# Outliers in Claim Amount:
# No outliers found.
# Outliers in Vested Bonus:
# No outliers found.
# Outliers in Interim Bonus:
# No outliers found.
# Outliers in Final Additional Bonus:
# No outliers found.
# Outliers in Premium:
# 263    20000.0
# Name: Premium, dtype: float64
# Outliers in Mode:
# No outliers found.

# %%
def visualize_with_capping(df):
    capped_df = df.copy()
    
    columns_to_cap = ['Plan', 'Premium']
    
    for col in columns_to_cap:
        q1 = capped_df[col].quantile(0.25)
        q3 = capped_df[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr
        capped_df[col] = capped_df[col].clip(lower=lower_bound, upper=upper_bound)

    num_cols = len(columns_to_cap)
    fig, axes = plt.subplots(num_cols, 1, figsize=(8, 5*num_cols))
    
    for i, col_name in enumerate(columns_to_cap):
        sns.boxplot(data=capped_df, y=col_name, ax=axes[i])
        axes[i].set_title(f'{col_name} - Boxplot')
        axes[i].set_ylabel('')
    
    plt.tight_layout()
    plt.show()

# Call the function
visualize_with_capping(df)

# %% [markdown]
# # One Hot Encoding

# %%
def one_hot_encode(df, columns):
    df_encoded = pd.get_dummies(df, columns=columns)
    return df_encoded

columns_to_encode = ['Plan', 'Policy Term', 'Mode']

df = one_hot_encode(df, columns_to_encode)

df
# Out:
#      Policy Number   Claim Amount  Vested Bonus  Interim Bonus  \
# 0        100614068   38563.221899  33701.647606    9339.244017
# 1        102314313   51666.039139  48711.268825    8972.874719
# 2        103484630   88906.524820  33410.777170    5533.966318
# 3        103807155  115663.536961  35299.418047    3548.046346
# 4        106977991   82153.702496  32676.704921    7189.802411
# ..             ...            ...           ...            ...
# 655      992994062   28307.261217  26322.799270    9544.529839
# 656      995226828  135585.986650   5754.263335    2457.847792
# 657      995619255  119383.675764   3047.881855    2687.171521
# 658      997677788   34245.539340  12329.503417    9509.902621
# 659      997835424   59483.283148  22964.141837    9940.657360
#
#      Final Additional Bonus      Premium  Anomaly Flag  Plan_14  Plan_75  \
# 0               6089.621520  4063.435561             0     True    False
# 1               8406.386946  3294.850477             0    False    False
# 2               3261.268054  1372.759863             0    False    False
# 3                394.057076  3083.742767             0    False    False
# 4               7869.917926  2106.719340             0    False     True
# ..                      ...          ...           ...      ...      ...
# 655             8895.742139  3974.582725             0    False    False
# 656             1312.057764  1385.207547             0    False    False
# 657              737.093896  1584.796212             0    False    False
# 658             4185.656861  4200.645575             0    False    False
# 659             8025.802829  4182.606997             1    False     True
#
#      Plan_106  Plan_111  Plan_801  Policy Term_8  Policy Term_10  \
# 0       False     False     False          False           False
# 1       False      True     False           True           False
# 2       False      True     False          False           False
# 3        True     False     False          False           False
# 4       False     False     False          False           False
# ..        ...       ...       ...            ...             ...
# 655     False     False      True          False           False
# 656     False      True     False          False           False
# 657     False     False      True           True           False
# 658     False      True     False          False           False
# 659     False     False     False          False           False
#
#      Policy Term_15  Policy Term_16  Policy Term_20  Mode_3  Mode_6  Mode_12
# 0             False           False            True    True   False    False
# 1             False           False           False    True   False    False
# 2             False           False            True   False   False     True
# 3             False           False            True    True   False    False
# 4              True           False           False   False    True    False
# ..              ...             ...             ...     ...     ...      ...
# 655           False           False            True    True   False    False
# 656            True           False           False   False   False     True
# 657           False           False           False    True   False    False
# 658            True           False           False   False   False     True
# 659           False           False            True    True   False    False
#
# [660 rows x 20 columns]

# %%
df.shape
# Out:
# (660, 20)

# %%
df.columns
# Out:
# Index(['Policy Number', 'Claim Amount', 'Vested Bonus', 'Interim Bonus',
#        'Final Additional Bonus', 'Premium', 'Anomaly Flag', 'Plan_14',
#        'Plan_75', 'Plan_106', 'Plan_111', 'Plan_801', 'Policy Term_8',
#        'Policy Term_10', 'Policy Term_15', 'Policy Term_16', 'Policy Term_20',
#        'Mode_3', 'Mode_6', 'Mode_12'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Policy Number   Claim Amount  Vested Bonus  Interim Bonus  \
# count   6.600000e+02     660.000000    660.000000     660.000000
# mean    5.368162e+08   89360.678463  24969.385179    4965.241710
# std     2.566467e+08   42786.075945  14305.343440    2946.656550
# min     1.006141e+08   10725.402497      0.000000       0.000000
# 25%     3.231482e+08   55757.494889  13068.237401    2429.554864
# 50%     5.315294e+08   87340.890238  25008.104368    4972.761946
# 75%     7.572095e+08  121159.523297  36438.648823    7526.236852
# max     9.978354e+08  198017.318405  49978.600351    9998.995526
#
#        Final Additional Bonus       Premium  Anomaly Flag
# count              660.000000    660.000000    660.000000
# mean              4908.834035   3033.502710      0.227273
# std               2966.336216   1300.846029      0.419388
# min                  0.000000    193.000000      0.000000
# 25%               2261.500676   2041.618086      0.000000
# 50%               4893.369514   3043.877088      0.000000
# 75%               7458.618681   3986.364273      0.000000
# max               9974.690996  20000.000000      1.000000

# %% [markdown]
# # Split The Dataset in X & Y

# %%
X = df.drop(columns=['Anomaly Flag'])  
Y = df['Anomaly Flag']

# %%
X.head()
# Out:
#    Policy Number   Claim Amount  Vested Bonus  Interim Bonus  \
# 0      100614068   38563.221899  33701.647606    9339.244017
# 1      102314313   51666.039139  48711.268825    8972.874719
# 2      103484630   88906.524820  33410.777170    5533.966318
# 3      103807155  115663.536961  35299.418047    3548.046346
# 4      106977991   82153.702496  32676.704921    7189.802411
#
#    Final Additional Bonus      Premium  Plan_14  Plan_75  Plan_106  Plan_111  \
# 0             6089.621520  4063.435561     True    False     False     False
# 1             8406.386946  3294.850477    False    False     False      True
# 2             3261.268054  1372.759863    False    False     False      True
# 3              394.057076  3083.742767    False    False      True     False
# 4             7869.917926  2106.719340    False     True     False     False
#
#    Plan_801  Policy Term_8  Policy Term_10  Policy Term_15  Policy Term_16  \
# 0     False          False           False           False           False
# 1     False           True           False           False           False
# 2     False          False           False           False           False
# 3     False          False           False           False           False
# 4     False          False           False            True           False
#
#    Policy Term_20  Mode_3  Mode_6  Mode_12
# 0            True    True   False    False
# 1           False    True   False    False
# 2            True   False   False     True
# 3            True    True   False    False
# 4           False   False    True    False

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Anomaly Flag, dtype: int64

# %%
Y.value_counts()
# Out:
# Anomaly Flag
# 0    510
# 1    150
# Name: count, dtype: int64

# %% [markdown]
# # Standarization

# %%
# from sklearn.preprocessing import StandardScaler
# scaler = StandardScaler()
# scaler.fit(X)
# SSX = scaler.transform(X)

# %% [markdown]
# # Balance the Data

# %%
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42)
X, Y = smote.fit_resample(X, Y)

# %%
X.shape
# Out:
# (1020, 19)

# %%
Y.value_counts()
# Out:
# Anomaly Flag
# 0    510
# 1    510
# Name: count, dtype: int64

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , Y_train , Y_test = train_test_split(X, Y, test_size=0.2, random_state = 7)

# %%
Y_train.shape ,Y_test.shape
# Out:
# ((816,), (204,))

# %%
X_train.shape ,X_test.shape
# Out:
# ((816, 19), (204, 19))

# %% [markdown]
# # Build Model

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# Define a pipeline with StandardScaler and SVC
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('svc', SVC())
])

# Define the parameter grid for grid search
param_grid = {
    'svc__C': [0.1, 1, 10],                     # Regularization parameter
    'svc__kernel': ['linear', 'rbf', 'poly'],   # Kernel type
    'svc__gamma': ['scale', 'auto', 0.1, 1]     # Kernel coefficient
}

# Initialize GridSearchCV
grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy', n_jobs=-1)

# Fit the grid search to the training data
grid_search.fit(X_train, Y_train)

# Get the best parameters and best estimator
best_params = grid_search.best_params_
best_estimator = grid_search.best_estimator_

# Print the best parameters
print("Best Parameters:", best_params)
print("Best Estimator:", best_estimator)

# Use the best estimator for prediction
Y_pred = best_estimator.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(Y_test, Y_pred)
print("Test Accuracy:", accuracy)
# Out:
# Best Parameters: {'svc__C': 1, 'svc__gamma': 'scale', 'svc__kernel': 'linear'}
# Best Estimator: Pipeline(steps=[('scaler', StandardScaler()),
#                 ('svc', SVC(C=1, kernel='linear'))])
# Test Accuracy: 0.8872549019607843

# %%
#Use Regression algorithm => SVC

from sklearn.svm import SVC
svc = SVC(C = 10, gamma = 1, kernel = 'rbf')
svc.fit(X_train, Y_train)
# Out:
# SVC(C=10, gamma=1)

# %% [markdown]
# # Make Prediction

# %%
svc_predict = svc.predict(X_test)

# %% [markdown]
# # Shap And Lime

# %%
X_test
# Out:
#      Policy Number   Claim Amount  Vested Bonus  Interim Bonus  \
# 723      702688889  170848.784010  15405.240137    3861.542843
# 668      256225293  123198.524209  28905.100698    2584.635651
# 171      328872698   25770.546543   7083.758842    8216.854015
# 551      834952627  153751.035449   2578.128916    6031.718746
# 334      537077308  124204.836654  35655.426634    5528.647885
# ..             ...            ...           ...            ...
# 74       199585092  114063.078773  41168.021869    7756.316499
# 253      421458838   50000.000000      0.000000       0.000000
# 499      765055833  100425.708505  31909.018351     310.820934
# 613      919795579   27426.501154  33674.992889    8167.285851
# 515      787194506   46648.734722  28119.297479    4296.431007
#
#      Final Additional Bonus      Premium  Plan_14  Plan_75  Plan_106  \
# 723             1829.776251  4128.989043    False    False     False
# 668              892.698929  1639.217940    False    False     False
# 171             8879.740438  3135.930351    False    False      True
# 551             1963.509925  1590.974755    False    False      True
# 334             8050.855692  1801.241532    False     True     False
# ..                      ...          ...      ...      ...       ...
# 74               323.827429  4565.188156    False    False     False
# 253                0.000000   193.000000    False    False     False
# 499             7644.837361  2446.409303    False    False      True
# 613             3916.014273  1327.894772    False    False     False
# 515             1899.842576  3280.640607    False     True     False
#
#      Plan_111  Plan_801  Policy Term_8  Policy Term_10  Policy Term_15  \
# 723     False      True           True           False           False
# 668      True     False          False           False            True
# 171     False     False          False           False            True
# 551     False     False          False           False            True
# 334     False     False           True           False           False
# ..        ...       ...            ...             ...             ...
# 74      False      True          False           False           False
# 253      True     False          False           False           False
# 499     False     False           True           False           False
# 613      True     False          False           False           False
# 515     False     False           True           False           False
#
#      Policy Term_16  Policy Term_20  Mode_3  Mode_6  Mode_12
# 723           False           False   False    True     True
# 668           False            True    True   False     True
# 171           False           False   False   False     True
# 551           False           False    True   False    False
# 334           False           False    True   False    False
# ..              ...             ...     ...     ...      ...
# 74            False            True   False   False     True
# 253           False            True    True   False    False
# 499           False           False   False   False     True
# 613           False            True   False    True    False
# 515           False           False   False    True    False
#
# [204 rows x 19 columns]

# %%
# import shap

# # Assuming 'classifier' is your trained classifier and 'X_test' is your test data
# explainer_rf = shap.TreeExplainer(classifier)

# # Select a single sample for explanation (e.g., the first sample)
# input_x = X_test.iloc[[0]]

# # Compute SHAP values for the selected sample
# shap_values_rf = explainer_rf.shap_values(input_x)

# # Adjusted SHAP values based on your specific needs (if necessary)
# shap_values_rf_adjusted = shap_values_rf[0][:, :-1]  # Adjusted SHAP values

# # Transpose the SHAP values if needed to match the format (num_samples, num_features)
# shap_values_rf_adjusted = shap_values_rf_adjusted.T  # Transpose SHAP values

# # Retrieve feature names corresponding to input data
# feature_names = input_x.columns.tolist()  # Convert DataFrame columns to list of names

# # Visualize SHAP values using the correct feature names/indices and input data values
# shap.summary_plot(shap_values_rf_adjusted, input_x.values, feature_names=feature_names)

# %%
# import lime
# import lime.lime_tabular

# # Create a LIME explainer
# explainer_lime = lime.lime_tabular.LimeTabularExplainer(X.values, feature_names=X_test, class_names=classifier.classes_)

# # Select an instance to explain (e.g., the first instance)
# instance_to_explain = X.values[0]

# # Explain the instance using LIME
# explanation = explainer_lime.explain_instance(instance_to_explain, classifier.predict_proba)
# explanation.show_in_notebook()  # Display the LIME explanation

# %% [markdown]
# # Model Evalutation

# %%
from sklearn.metrics import accuracy_score

print("Train Accuracy of Support Vector Machine :",svc.score(X_train,Y_train)*100)
print("Test Accuracy of Support Vector Machine :",svc.score(X_test,Y_test)*100)
print("Accuracy Score of Support Vector Machine :",accuracy_score(Y_test,svc_predict)*100)
# Out:
# Train Accuracy of Support Vector Machine : 100.0
# Test Accuracy of Support Vector Machine : 48.529411764705884
# Accuracy Score of Support Vector Machine : 48.529411764705884

# %%
#Confusion Matrix and Classifiaction Report of Support Vector Machine(SVM)
 
from sklearn.metrics import classification_report,confusion_matrix
cm = confusion_matrix(Y_test,svc_predict)
sns.heatmap(confusion_matrix(Y_test,svc_predict),annot=True,fmt='d')
# Out:
# <Axes: >

# %%
print("Classification Report of Support Vector Machine :\n ",classification_report(Y_test,svc_predict))
# Out:
# Classification Report of Support Vector Machine :
#                 precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       105
#            1       0.49      1.00      0.65        99
#
#     accuracy                           0.49       204
#    macro avg       0.24      0.50      0.33       204
# weighted avg       0.24      0.49      0.32       204
# C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:1497: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import shap

# Assuming 'svc' is your trained SVC model and 'X_test' is your test data
explainer_svc = shap.KernelExplainer(svc.predict, X_train)

# Select a single sample for explanation (e.g., the first sample)
input_x = X_test.iloc[[0]]

# Compute SHAP values for the selected sample
shap_values_svc = explainer_svc.shap_values(input_x)

# Retrieve feature names corresponding to input data
feature_names = input_x.columns.tolist()  # Convert DataFrame columns to list of names

# Visualize SHAP values using the correct feature names/indices and input data values
shap.summary_plot(shap_values_svc, input_x, feature_names=feature_names)
# Out:
# Using 816 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1 [00:00<?, ?it/s]
